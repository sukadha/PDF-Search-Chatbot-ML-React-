# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pymupdf scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 53.9 MB/s eta 0:00:00
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Ensure text extraction
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing special characters and extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def find_relevant_text(query, document):
    """Checks if the query is present in the document and displays relevant content."""
    query = query.lower().strip()  # Normalize input query
    if query in document:
        return f"Data Found: {query}\nExtracted Text: {get_surrounding_text(document, query)}"
    return "Not Found"

def get_surrounding_text(text, query, window=100):
    """Extracts surrounding text where the query appears in the document."""
    index = text.find(query)
    if index == -1:
        return "Not Found"

    start = max(0, index - window)  # Extract some surrounding context
    end = min(len(text), index + len(query) + window)
    return text[start:end]

def main():
    pdf_path = "/content/drive/MyDrive/resume/Resume New.pdf"  # Change as needed
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# Enter your query (or type 'exit' to quit): nirmal high school
# Not Found
# Enter your query (or type 'exit' to quit): Kopparthi Lakshmi Sukadha
# Data Found: kopparthi lakshmi sukadha
# Extracted Text:  kopparthi lakshmi sukadha portafolio.com 7842872322 machilipatnam, india koppa r t hi l a kshm i suka dha 30@gmail. com https
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ee4299c77977> in <cell line: 0>()
#      45
#      46 if __name__ == "__main__":
# ---> 47     main()
#
# <ipython-input-9-ee4299c77977> in main()
#      37
#      38     while True:
# ---> 39         user_query = input("Enter your query (or type 'exit' to quit): ").strip()
#      40         if user_query.lower() == "exit":
#      41             break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Ensure text extraction
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing special characters and extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def find_relevant_text(query, document):
    """Checks if the query is present in the document and displays relevant content."""
    query = query.lower().strip()  # Normalize input query
    if query in document:
        return f"Data Found: {query}\nExtracted Text: {get_surrounding_text(document, query)}"
    return "Not Found"

def get_surrounding_text(text, query, window=100):
    """Extracts surrounding text where the query appears in the document."""
    index = text.find(query)
    if index == -1:
        return "Not Found"

    start = max(0, index - window)  # Extract some surrounding context
    end = min(len(text), index + len(query) + window)
    return text[start:end]

def main():
    pdf_path = "/content/drive/MyDrive/resume/JavaCheatSheet.pdf"  # Change as needed
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# Enter your query (or type 'exit' to quit): JAVA COLLECTIONS
# Data Found: java collections
# Extracted Text: e extends keyword here applies as well to interfaces, so a can be an interface that extends list<b> java collections: list<t>: similar to arrays arraylist<t>: slow insert into middle //arraylist has fast random acces
# Enter your query (or type 'exit' to quit): IF STATEMENTS:
# Data Found: if statements:
# Extracted Text: th.floor(num) ,math.log(num),math.max(a,b),math.min(c,d), math.pow(a,b),math.round(a),math.random() if statements: if( boolean_value ) { statements } else if( bool ) { statements } else if( ..etc ) { statements } e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fd18783b5cee> in <cell line: 0>()
#      45
#      46 if __name__ == "__main__":
# ---> 47     main()
#
# <ipython-input-7-fd18783b5cee> in main()
#      37
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Extract text
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing special characters and extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def find_relevant_text(query, document):
    """Finds relevant text in the document and extracts meaningful information."""
    query = query.lower().strip()  # Normalize query
    sentences = re.split(r'(?<=[.!?])\s+', document)  # Split text into sentences

    for sentence in sentences:
        if query in sentence:  # Check if query appears in a sentence
            return f"✅ Data Found: {query}\n📌 Extracted Text: {sentence.strip()}"

    return "❌ Not Found"

def main():
    pdf_path = "/content/drive/MyDrive/resume/Resume New.pdf"  # Change to your PDF file path
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Enter your query (or type 'exit' to quit): Employee Promotions using Machine Learning
# ✅ Data Found: employee promotions using machine learning
# 📌 Extracted Text: intermediate in m.p.c 8.5/10.0cgpa projects nov 2023-dec2023 employee promotions using machine learning i had worked on employee promotion dataset whether the employee is eligible or not.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d5a289470736> in <cell line: 0>()
#      39
#      40 if __name__ == "__main__":
# ---> 41     main()
#
# <ipython-input-9-d5a289470736> in main()
#      31
#      32     while True:
# ---> 33         user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
#      34         if user_query.lower() == "exit":
#      35             break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Extract text
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def extract_main_data(sentence, query):
    """Extracts only the main information from a sentence."""
    # Remove numbers, CGPA, and unwanted words
    sentence = re.sub(r'\b\d+(\.\d+)?\b', '', sentence)  # Remove numbers like 8.5, 2023, etc.
    sentence = re.sub(r'cgpa|projects|nov|dec', '', sentence)  # Remove unwanted words
    sentence = sentence.strip()

    # Ensure query is highlighted correctly
    if query in sentence:
        return f"✅ Data Found: {query}\n📌 Extracted Text: {sentence.strip()}"

    return "❌ Not Found"

def find_relevant_text(query, document):
    """Finds relevant text and extracts the most important information."""
    query = query.lower().strip()  # Normalize query
    sentences = re.split(r'(?<=[.!?])\s+', document)  # Split text into sentences

    for sentence in sentences:
        if query in sentence:  # Check if query appears in a sentence
            return extract_main_data(sentence, query)

    return "❌ Not Found"

def main():
    pdf_path = "/content/drive/MyDrive/resume/Resume New.pdf"  # Change to your PDF file path
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Enter your query (or type 'exit' to quit): Employee Promotions using Machine Learning
# ✅ Data Found: employee promotions using machine learning
# 📌 Extracted Text: intermediate in m.p.c /.0   -2023 employee promotions using machine learning i had worked on employee promotion dataset whether the employee is eligible or not.
# 🔍 Enter your query (or type 'exit' to quit): Nirmala High School.
# ✅ Data Found: nirmala high school.
# 📌 Extracted Text: intermediate in m.p.c /.0  -  nirmala high school.
# 🔍 Enter your query (or type 'exit' to quit): AI and ML Intern Henotic Technology Pvt Ltd, Hyderabad
# ✅ Data Found: ai and ml intern henotic technology pvt ltd, hyderabad
# 📌 Extracted Text: internship july -aug  ai and ml intern henotic technology pvt ltd, hyderabad during my internship experience has been invaluable in the both personal and professional growth.
# ---------------------------------------------------------------------------
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Extract text from all pages
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing special characters and extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def preprocess_query(query):
    """Handles variations like 'What is ...' and extracts the main keyword."""
    query = query.lower().strip()

    # Remove common question phrases
    query = re.sub(r"^(what is|who is|tell me about|define)\s+", "", query)
    return query

def find_relevant_text(query, document):
    """Finds the most relevant text and extracts meaningful information."""
    query = preprocess_query(query)  # Normalize query

    if query in document:
        return f"✅ Data Found: {query}\n📌 Extracted Text: {get_surrounding_text(document, query)}"

    return "❌ Not Found"

def get_surrounding_text(text, query, window=100):
    """Extracts surrounding text where the query appears in the document."""
    index = text.find(query)
    if index == -1:
        return "Not Found"

    start = max(0, index - window)  # Extract some surrounding context
    end = min(len(text), index + len(query) + window)
    return text[start:end]

def main():
    pdf_path = "/content/drive/MyDrive/resume/Resume New.pdf"  # Change as needed
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Enter your query (or type 'exit' to quit): who is Kopparthi Lakshmi Sukadha
# ✅ Data Found: kopparthi lakshmi sukadha
# 📌 Extracted Text:  kopparthi lakshmi sukadha portafolio.com 7842872322 machilipatnam, india koppa r t hi l a kshm i suka dha 30@gmail. com https
# 🔍 Enter your query (or type 'exit' to quit): explain about Kopparthi Lakshmi Sukadha
# ❌ Not Found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a84390d268af> in <cell line: 0>()
#      55
#      56 if __name__ == "__main__":
# ---> 57     main()
#
# <ipython-input-3-a84390d268af> in main()
#      47
#      48     while True:
# ---> 49         user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
#      50         if user_query.lower() == "exit":
#      51             break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Extract text from all pages
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing special characters and extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def preprocess_query(query):
    """Removes unnecessary words like 'explain', 'who is', 'what is' and extracts main keyword."""
    query = query.lower().strip()

    # Remove common question phrases and keep only the main subject
    query = re.sub(r"^(who is|what is|explain|tell me about|define|describe|give details about|talk about)\s+", "", query)

    return query

def find_relevant_text(query, document):
    """Finds the most relevant text and extracts meaningful information."""
    query = preprocess_query(query)  # Normalize query

    if query in document:
        return f"✅ Data Found: {query}\n📌 Extracted Text: {get_surrounding_text(document, query)}"

    return "❌ Not Found"

def get_surrounding_text(text, query, window=150):
    """Extracts surrounding text where the query appears in the document."""
    index = text.find(query)
    if index == -1:
        return "Not Found"

    start = max(0, index - window)  # Extract some surrounding context
    end = min(len(text), index + len(query) + window)
    return text[start:end]

def main():
    pdf_path = "/content/drive/MyDrive/resume/Resume New.pdf"  # Change as needed
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Enter your query (or type 'exit' to quit): hi Kopparthi Lakshmi Sukadha
# ❌ Not Found
# 🔍 Enter your query (or type 'exit' to quit): whom Kopparthi Lakshmi Sukadha
# ❌ Not Found
# 🔍 Enter your query (or type 'exit' to quit): what is Kopparthi Lakshmi Sukadha
# ✅ Data Found: kopparthi lakshmi sukadha
# 📌 Extracted Text:  kopparthi lakshmi sukadha portafolio.com 7842872322 machilipatnam, india koppa r t hi l a kshm i suka dha 30@gmail. com https://github.com/sukadha https://www.linkedin.com/in/
# 🔍 Enter your query (or type 'exit' to quit): tell me about skills
# ✅ Data Found: skills
# 📌 Extracted Text: pparthi- lakshmi-sukadha summary computer science student with a passion for solving problems through tech innovation. looking to improve programming skills, gain hands-on software experience, and contribute to dynamic projects. skills languages:  c  c++  java  python  machine learning education 2021
# 🔍 Enter your query (or type 'exit' to quit): explain about the languages
# ...

# %%
import fitz  # PyMuPDF
import re

def extract_text_from_pdf(pdf_path):
    """Extracts text from a given PDF file."""
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])  # Extract text from all pages
    doc.close()
    return text

def clean_text(text):
    """Cleans extracted text by removing special characters and extra spaces."""
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    return text.lower()  # Convert to lowercase for case-insensitive search

def preprocess_query(query):
    """Removes unnecessary words like 'explain', 'who is', 'what is' and extracts the main keyword."""
    query = query.lower().strip()

    # List of question words/phrases to ignore
    ignore_phrases = [
        "who is", "what is", "explain", "tell me about", "define", "describe",
        "give details about", "talk about", "information on", "give me info about",
        "show details of", "i want to know about", "can you tell me about"
    ]

    # Remove matching question phrases
    for phrase in ignore_phrases:
        if query.startswith(phrase):
            query = query[len(phrase):].strip()
            break  # Remove only the first matching phrase

    return query

def find_relevant_text(query, document):
    """Finds the most relevant text and extracts meaningful information."""
    query = preprocess_query(query)  # Normalize query

    if query in document:
        return f"✅ Data Found: {query}\n📌 Extracted Text: {get_surrounding_text(document, query)}"

    return "❌ Not Found"

def get_surrounding_text(text, query, window=150):
    """Extracts surrounding text where the query appears in the document."""
    index = text.find(query)
    if index == -1:
        return "Not Found"

    start = max(0, index - window)  # Extract some surrounding context
    end = min(len(text), index + len(query) + window)
    return text[start:end]

def main():
    pdf_path = "/content/drive/MyDrive/resume/Resume New.pdf"  # Change as needed
    extracted_text = extract_text_from_pdf(pdf_path)
    cleaned_text = clean_text(extracted_text)

    while True:
        user_query = input("🔍 Enter your query (or type 'exit' to quit): ").strip()
        if user_query.lower() == "exit":
            break

        result = find_relevant_text(user_query, cleaned_text)
        print(result)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Enter your query (or type 'exit' to quit): talk about Kopparthi Lakshmi Sukadha
# ✅ Data Found: kopparthi lakshmi sukadha
# 📌 Extracted Text:  kopparthi lakshmi sukadha portafolio.com 7842872322 machilipatnam, india koppa r t hi l a kshm i suka dha 30@gmail. com https://github.com/sukadha https://www.linkedin.com/in/
# 🔍 Enter your query (or type 'exit' to quit): talk about mahathi
# ❌ Not Found
# 🔍 Enter your query (or type 'exit' to quit): what is skills
# ✅ Data Found: skills
# 📌 Extracted Text: pparthi- lakshmi-sukadha summary computer science student with a passion for solving problems through tech innovation. looking to improve programming skills, gain hands-on software experience, and contribute to dynamic projects. skills languages:  c  c++  java  python  machine learning education 2021
# 🔍 Enter your query (or type 'exit' to quit): who is Kopparthi Lakshmi Sukadha
# ✅ Data Found: kopparthi lakshmi sukadha
# ...
